# %%
import sys
sys.path.append('clustering/')
from utils import *

# %%
from gensim.models import KeyedVectors
import os

wv = KeyedVectors.load(os.path.join(get_data_dir(), '2010s/Word2Vec', 'vectors.kv'))
# Out:
# data_dir:  /home/lyuzhuoqi/projects/clustering/data

# %%
len(wv)
# Out:
# 37594

# %%
wv.get_vector(137773608)
# Out:
# array([ 0.32722086, -0.15711217,  0.20375852,  0.33739048, -0.19772862,
#        -0.4076014 ,  0.07415517, -0.09840615,  0.31147614, -0.2745547 ,
#        -0.17125258, -0.06052527, -0.19595414, -0.2154053 ,  0.24389395,
#        -0.15374835,  0.36450416,  0.25323406,  0.38298318, -0.46327364,
#         0.3597798 , -0.29393438, -0.26204574, -0.15576246,  0.05969739,
#         0.10048518, -0.42264116,  0.32576838,  0.38706452,  0.08289913,
#         0.16033615,  0.08293691, -0.00511011,  0.21733387, -0.02283357,
#         0.64248717,  0.02492782,  0.24401993,  0.01990879,  0.01911439,
#         0.313904  , -0.3707749 , -0.04474055,  0.39612845, -0.35110044,
#         0.10889114,  0.29449514, -0.2926584 ,  0.12686746,  0.5258949 ,
#        -0.08361237,  0.4988966 ,  0.1320855 , -0.34636492,  0.15383698,
#         0.13074952,  0.22744676, -0.1562459 , -0.3041114 , -0.13013825,
#        -0.14612487, -0.13467523,  0.02900542,  0.19487567, -0.023074  ,
# ...

# %%
import json

# Load the vertex id to index mapping
mapping_path = os.path.join(get_data_dir(), '2010s/direct_citation', 'vid_to_index.json')
with open(mapping_path, 'r') as f:
    vid_to_index = json.load(f)
print("VID to index mapping loaded successfully!")
# Out:
# data_dir:  /home/lyuzhuoqi/projects/clustering/data
# VID to index mapping loaded successfully!

# %%
vid_to_index
# Out:
# {'173952182.0': 0,
#  '1127419992.0': 1,
#  '2755639217.0': 2,
#  '195356620.0': 3,
#  '99535875.0': 4,
#  '113449338.0': 5,
#  '1196868077.0': 6,
#  '26277462.0': 7,
#  '2755612976.0': 8,
#  '2312674.0': 9,
#  '40639335.0': 10,
#  '2764430319.0': 11,
#  '2755952065.0': 12,
#  '81453128.0': 13,
#  '22240167.0': 14,
#  '198727964.0': 15,
#  '1175727152.0': 16,
#  '2764481359.0': 17,
#  '2759168861.0': 18,
#  '122096800.0': 19,
#  '2736389702.0': 20,
#  '2764994983.0': 21,
#  '170977379.0': 22,
#  '98107870.0': 23,
#  '187416585.0': 24,
#  '2764491503.0': 25,
#  '2898580591.0': 26,
#  '89143414.0': 27,
#  '1140961231.0': 28,
#  '134644764.0': 29,
#  '43790123.0': 30,
#  '2756351210.0': 31,
#  '1123621769.0': 32,
#  '2755385796.0': 33,
#  '7571225.0': 34,
#  '1176326080.0': 35,
#  '2754527366.0': 36,
#  '2755575508.0': 37,
#  '171625771.0': 38,
#  '2757547734.0': 39,
#  '134546602.0': 40,
#  '1167275352.0': 41,
#  '126530969.0': 42,
#  '138241747.0': 43,
#  '146636433.0': 44,
# ...
